# %% [markdown]
# <a href="https://colab.research.google.com/github/viplove21r/Job-Analysis-2026/blob/main/1_EDA_Intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing Libraries
import ast
import pandas as pd
import seaborn as sns
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %% [markdown]
# # **Filter For Data Analyst Jobs In India**

# %%
df_india=df[(df["job_country"]=="India") & (df["job_title_short"]=="Data Analyst")]

# %%
df_plot=df_india["job_location"].value_counts().head(10).to_frame()

sns.set_theme(style="ticks")
sns.barplot(df_plot, x="count", y="job_location",hue="count", palette="dark:b_r", legend=False)
sns.despine()
plt.title('Counts of Job Locations for Data Analyst in India')
plt.xlabel('Number of Jobs')
plt.ylabel('')
plt.show()

# %% [markdown]
# **Additional Offerings/Requirements**

# %%
dict_column = {
    'job_work_from_home': 'Work from Home Offered',
    'job_no_degree_mention': 'Degree Requirement',
    'job_health_insurance': 'Health Insurance Offered'
}

fig, ax = plt.subplots(1, 3)
fig.set_size_inches((12, 5))

for i, (column, title) in enumerate(dict_column.items()):
  counts = df_india[column].value_counts()

  ax[i].pie(
        counts,
        labels=counts.index.astype(str),
        autopct='%1.1f%%',
        startangle=90
    )

  ax[i].set_title(title)

# plt.suptitle('Benefit Analysis of Data Jobs', fontsize=16)

plt.show()

# %% [markdown]
# **Companies to Explore:**

# %%
df_plot = df_india['company_name'].value_counts().head(10).to_frame()

sns.set_theme(style='ticks')
sns.barplot(data=df_plot, x='count', y='company_name', hue='count', palette='dark:b_r', legend=False)
sns.despine()
plt.title('Companies offering Data Analyst jobs in India')
plt.xlabel('Number of Jobs')
plt.ylabel('')
plt.show()

# %% [markdown]
# # **Filter For Machine Learning Engineer Jobs In India**

# %%
df_india_ml=df[(df["job_country"]=="India") & (df["job_title_short"]=="Machine Learning Engineer")]

# %%
df_plot_ml = df_india_ml['job_location'].value_counts().head(10).to_frame()

sns.set_theme(style='ticks')
sns.barplot(data=df_plot_ml, x='count', y='job_location', hue='count', palette='dark:b_r', legend=False)
sns.despine()
plt.title('Counts of Job Locations for Machine Learning Engineer in India')
plt.xlabel('Number of Jobs')
plt.ylabel('')
plt.show()

# %% [markdown]
# **Additional Offerings/Requirements**

# %%
dict_column = {
    'job_work_from_home': 'Work from Home Offered',
    'job_no_degree_mention': 'Degree Requirement',
    'job_health_insurance': 'Health Insurance Offered'
}

fig, ax = plt.subplots(1, 3)
fig.set_size_inches((12, 5))

for i, (column, title) in enumerate(dict_column.items()):
  counts = df_india_ml[column].value_counts()

  ax[i].pie(
        counts,
        labels=counts.index.astype(str),
        autopct='%1.1f%%',
        startangle=90
    )

  ax[i].set_title(title)


plt.show()

# %% [markdown]
# **Companies to Explore:**

# %%
df_plot = df_india_ml['company_name'].value_counts().head(10).to_frame()

sns.set_theme(style='ticks')
sns.barplot(data=df_plot, x='count', y='company_name', hue='count', palette='dark:b_r', legend=False)
sns.despine()
plt.title('Companies offering Machine Learning Engineer jobs in India')
plt.xlabel('Number of Jobs')
plt.ylabel('')
plt.show()
